# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

#used the program Numbers to rename and file
df = pd.read_csv('Desktop/data_scientist/WELLCOME_APCspend2013_forThinkful2.csv', index_col=0)

# %% [markdown]
# ### Inpecting the DATA

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2127 entries, nan to PMID: 23846567  (Epub July 2013)
# Data columns (total 4 columns):
# Publisher                                              2127 non-null object
# Journal title                                          2126 non-null object
# Article title                                          2127 non-null object
# COST (£) charged to Wellcome (inc VAT when charged)    2127 non-null object
# dtypes: object(4)
# memory usage: 83.1+ KB
#        Publisher Journal title  \
# count       2127          2126
# unique       299           984
# top     Elsevier      PLoS One
# freq         387            92
#
#                                             Article title  \
# count                                                2127
# unique                                               2126
# top     Exclusive breastfeeding, diarrhoel morbidity a...
# freq                                                    2
#
# ...

# %%
df.head()
# Out:
#                      Publisher           Journal title  \
# PMID/PMCID
# NaN                        CUP  Psychological Medicine
# PMC3679557                 ACS       Biomacromolecules
# 23043264  PMC3506128       ACS              J Med Chem
# 23438330 PMC3646402        ACS              J Med Chem
# 23438216 PMC3601604        ACS              J Org Chem
#
#                                                           Article title  \
# PMID/PMCID
# NaN                   Reduced parahippocampal cortical thickness in ...
# PMC3679557            Structural characterization of a Model Gram-ne...
# 23043264  PMC3506128  Fumaroylamino-4,5-epoxymorphinans and related ...
# 23438330 PMC3646402   Orvinols with mixed kappa/mu opioid receptor a...
# 23438216 PMC3601604   Regioselective opening of myo-inositol orthoes...
#
#                      COST (£) charged to Wellcome (inc VAT when charged)
# PMID/PMCID
# NaN                                                               £0.00
# ...

# %%
df.tail()
# Out:
#                                                       Publisher  \
# PMID/PMCID
# 2901593                                   Wolters Kluwer Health
# 3748854                                  Wolters Kluwer Health
# 3785148                                  Wolters Kluwer Health
# PMCID:\n    PMC3647051            Wolters Kluwer N.V./Lippinott
# PMID: 23846567  (Epub July 2013)                Wolters Kluwers
#
#                                                                     Journal title  \
# PMID/PMCID
# 2901593                                                      Circulation Research
# 3748854                                                                      AIDS
# 3785148                                                      Pediatr Infect Dis J
# PMCID:\n    PMC3647051                                                       AIDS
# PMID: 23846567  (Epub July 2013)  Journal of Acquired Immune Deficiency Syndromes
#
# ...

# %%
df.columns
# Out:
# Index(['Publisher', 'Journal title', 'Article title',
#        'COST (£) charged to Wellcome (inc VAT when charged)'],
#       dtype='object')

# %%
df.rename(columns={"COST (£) charged to Wellcome (inc VAT when charged)": "Cost"})
# Out:
#                                                                      Publisher  \
# PMID/PMCID
# NaN                                                                        CUP
# PMC3679557                                                                 ACS
# 23043264  PMC3506128                                                       ACS
# 23438330 PMC3646402                                                        ACS
# 23438216 PMC3601604                                                        ACS
# PMC3579457                                                                 ACS
# PMC3709265                                                                 ACS
# 23057412 PMC3495574                                                        ACS
# PMCID: PMC3780468                 ACS (Amercian Chemical Society) Publications
# PMCID: PMC3621575                 ACS (Amercian Chemical Society) Publications
# PMCID: PMC3739413                 ACS (Amercian Chemical Society) Publications
# ...

# %%
df.shape
# Out:
# (2127, 4)

# %%
#unique publisher data
df.Publisher.unique()
# Out:
# array(['CUP', 'ACS', 'ACS (Amercian Chemical Society) Publications',
#        'ACS Publications', 'AGA Institute', 'AMBSB',
#        'American Association of Immunologists',
#        'American Chemical Society', 'AMERICAN CHEMICAL SOCIETY',
#        'American Chemical Society Publications',
#        'American College of Chest Physicians',
#        'American Physiological Society',
#        'American Psychiatric Association',
#        'American Psychiatric Publishing',
#        'American Psychological Association',
#        'American Psychological Association ',
#        'American Public Health Association',
#        'American Soc for Biochemistry and Molecular Biology',
#        'American Society for Biochemistry and Molecular Biolgy',
#        'American Society for Biochemistry and Molecular Biology',
#        'American Society for Biochemistry and Molecular Biology ',
#        'American Society for Investigative Pathology',
#        'American Society for Microbiology',
# ...

# %%
#remove leading and trailing spaces
df['Publisher'] = df['Publisher'].str.strip()

# %%
df.Publisher.unique()
# Out:
# array(['CUP', 'ACS', 'ACS (Amercian Chemical Society) Publications',
#        'ACS Publications', 'AGA Institute', 'AMBSB',
#        'American Association of Immunologists',
#        'American Chemical Society', 'AMERICAN CHEMICAL SOCIETY',
#        'American Chemical Society Publications',
#        'American College of Chest Physicians',
#        'American Physiological Society',
#        'American Psychiatric Association',
#        'American Psychiatric Publishing',
#        'American Psychological Association',
#        'American Public Health Association',
#        'American Soc for Biochemistry and Molecular Biology',
#        'American Society for Biochemistry and Molecular Biolgy',
#        'American Society for Biochemistry and Molecular Biology',
#        'American Society for Investigative Pathology',
#        'American Society for Microbiology',
#        'American Society for Nutrition',
#        'American Society of Haematology',
# ...

# %%
#make everything same case format
df['Publisher'] = df['Publisher'].str.title()
df.Publisher.unique()
#looking into regular expressions to match all the data
# Out:
# array(['Cup', 'Acs', 'Acs (Amercian Chemical Society) Publications',
#        'Acs Publications', 'Aga Institute', 'Ambsb',
#        'American Association Of Immunologists',
#        'American Chemical Society',
#        'American Chemical Society Publications',
#        'American College Of Chest Physicians',
#        'American Physiological Society',
#        'American Psychiatric Association',
#        'American Psychiatric Publishing',
#        'American Psychological Association',
#        'American Public Health Association',
#        'American Soc For Biochemistry And Molecular Biology',
#        'American Society For Biochemistry And Molecular Biolgy',
#        'American Society For Biochemistry And Molecular Biology',
#        'American Society For Investigative Pathology',
#        'American Society For Microbiology',
#        'American Society For Nutrition',
#        'American Society Of Haematology',
# ...

# %%
# overwriting column with replaced value
df["Publisher"]= df["Publisher"].replace(["Acs (Amercian Chemical Society) Publications","Acs Publications"], "ACS") 

# creating a filter for column  
filter = df["Publisher"]=="Acs"
  
# printing only filtered columns 
df.where(filter).dropna()
# Out:
#                      Publisher                                 Journal title  \
# PMID/PMCID
# PMC3679557                 Acs                             Biomacromolecules
# 23043264  PMC3506128       Acs                                    J Med Chem
# 23438330 PMC3646402        Acs                                    J Med Chem
# 23438216 PMC3601604        Acs                                    J Org Chem
# PMC3579457                 Acs                Journal of Medicinal Chemistry
# PMC3709265                 Acs                  Journal of Proteome Research
# 23057412 PMC3495574        Acs                                     Mol Pharm
# PMCID: PMC3780468          Acs                          ACS Chemical Biology
# PMCID: PMC3621575          Acs                          ACS Chemical Biology
# PMCID: PMC3739413          Acs  Journal of Chemical Information and Modeling
# PMCID: PMC3530961          Acs                Journal of Medicinal Chemistry
# ...

# %%
df.Publisher.unique()
# Out:
# array(['Cup', 'Acs', 'Aga Institute', 'Ambsb',
#        'American Association Of Immunologists',
#        'American Chemical Society',
#        'American Chemical Society Publications',
#        'American College Of Chest Physicians',
#        'American Physiological Society',
#        'American Psychiatric Association',
#        'American Psychiatric Publishing',
#        'American Psychological Association',
#        'American Public Health Association',
#        'American Soc For Biochemistry And Molecular Biology',
#        'American Society For Biochemistry And Molecular Biolgy',
#        'American Society For Biochemistry And Molecular Biology',
#        'American Society For Investigative Pathology',
#        'American Society For Microbiology',
#        'American Society For Nutrition',
#        'American Society Of Haematology',
#        'American Society Of Hamatology', 'American Society Of Hematology',
#        'American Society Of Human Genetics (Elsevier)',
# ...

# %%
df["Publisher"]= df["Publisher"].replace(["American Chemical Society"], "American Chemical Society Publications") 
df["Publisher"]= df["Publisher"].replace(["American Soc For Biochemistry And Molecular Biology","merican Society For Biochemistry And Molecular Biolgy"], "American Society For Biochemistry And Molecular Biology") 
df["Publisher"]= df["Publisher"].replace(["Acs (Amercian Chemical Society) Publications","Acs Publications"], "ACS") 
df["Publisher"]= df["Publisher"].replace(["Acs (Amercian Chemical Society) Publications","Acs Publications"], "ACS") 
df["Publisher"]= df["Publisher"].replace(["Acs (Amercian Chemical Society) Publications","Acs Publications"], "ACS")

# %%
# remove THE in the beginning of the sentence
df["Publisher"]= df["Publisher"].replace(["\SThe\b"], "") 
df.Publisher.unique()
# Out:
# array(['Cup', 'Acs', 'Aga Institute', 'Ambsb',
#        'American Association Of Immunologists',
#        'American Chemical Society',
#        'American Chemical Society Publications',
#        'American College Of Chest Physicians',
#        'American Physiological Society',
#        'American Psychiatric Association',
#        'American Psychiatric Publishing',
#        'American Psychological Association',
#        'American Public Health Association',
#        'American Soc For Biochemistry And Molecular Biology',
#        'American Society For Biochemistry And Molecular Biolgy',
#        'American Society For Biochemistry And Molecular Biology',
#        'American Society For Investigative Pathology',
#        'American Society For Microbiology',
#        'American Society For Nutrition',
#        'American Society Of Haematology',
#        'American Society Of Hamatology', 'American Society Of Hematology',
#        'American Society Of Human Genetics (Elsevier)',
# ...

# %% [markdown]
# ### What are the five most common journals and the total articles for each?

# %%
#make sure all data are numbers
#remove currency
#remove rows with no data or string data

# %% [markdown]
# ### Calculate the mean, median and standard deviation of the open-access cost per article for each journal?
